# %% [markdown]
# <a href="https://colab.research.google.com/github/crudables/Data-Analys/blob/main/Motor%20Fuel%20efficiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_18 = pd.read_csv('https://raw.githubusercontent.com/crudables/Data-Analys/main/all_alpha_18.csv')
df_08 = pd.read_csv('https://raw.githubusercontent.com/crudables/Data-Analys/main/all_alpha_08.csv')
df_18.head()

# %%
df_18.shape
# Out:
# (1611, 18)

# %%
df_08.shape
# Out:
# (2404, 18)

# %%
df_08[df_08.duplicated()]
# Out:
#                     Model  Displ      Cyl    Trans Drive      Fuel Sales Area  \
# 752   DODGE Sprinter 2500    3.5      NaN      NaN   NaN  Gasoline         FA
# 754   DODGE Sprinter 2500    3.5      NaN      NaN   NaN  Gasoline         CA
# 769             FORD E150    4.6      NaN      NaN   NaN  Gasoline         FA
# 771             FORD E150    4.6      NaN      NaN   NaN  Gasoline         CA
# 773             FORD E150    5.4      NaN      NaN   NaN  Gasoline         FA
# 775             FORD E150    5.4      NaN      NaN   NaN  Gasoline         CA
# 794             FORD E350    5.4      NaN      NaN   NaN  Gasoline         FA
# 797             FORD E350    5.4      NaN      NaN   NaN  Gasoline         CA
# 800             FORD E350    5.4      NaN      NaN   NaN  Gasoline         FA
# 958     FREIGHTLINER 2500    3.5      NaN      NaN   NaN  Gasoline         FA
# 960     FREIGHTLINER 2500    3.5      NaN      NaN   NaN  Gasoline         CA
# ...

# %%
df_18[df_18.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Cert Region, Stnd, Stnd Description, Underhood ID, Veh Class, Air Pollution Score, City MPG, Hwy MPG, Cmb MPG, Greenhouse Gas Score, SmartWay, Comb CO2]
# Index: []

# %%
df_08.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales Area               object
# Stnd                     object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score      object
# FE Calc Appr             object
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Unadj Cmb MPG           float64
# Greenhouse Gas Score     object
# SmartWay                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                     float64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert Region              object
# Stnd                     object
# Stnd Description         object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score       int64
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Greenhouse Gas Score      int64
# SmartWay                 object
# Comb CO2                 object
# dtype: object

# %%
df_08.describe()
# Out:
#              Displ  Unadj Cmb MPG
# count  2404.000000    2205.000000
# mean      3.748918      23.916104
# std       1.335785       6.366170
# min       1.300000      10.018400
# 25%       2.500000      19.113900
# 50%       3.500000      23.921300
# 75%       4.800000      27.869300
# max       8.400000      65.777800

# %%
df_08.isnull().values.sum()
# Out:
# 1685

# %%
df_08.shape
# Out:
# (2404, 18)

# %%
df_08.isnull().any(axis=1).sum()
# Out:
# 199

# %%
df_08.tail(100)
# Out:
#                                   Model  Displ      Cyl    Trans Drive  \
# 2304  VOLKSWAGEN New Beetle Convertible    2.5  (5 cyl)    Man-5   2WD
# 2305  VOLKSWAGEN New Beetle Convertible    2.5  (5 cyl)  Auto-S6   2WD
# 2306  VOLKSWAGEN New Beetle Convertible    2.5  (5 cyl)    Man-5   2WD
# 2307                  VOLKSWAGEN Passat    2.0  (4 cyl)  Auto-S6   2WD
# 2308                  VOLKSWAGEN Passat    2.0  (4 cyl)    Man-6   2WD
# ...                                 ...    ...      ...      ...   ...
# 2399                        VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD
# 2400                        VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD
# 2401                        VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD
# 2402                        VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD
# 2403                        VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD
#
#           Fuel Sales Area Stnd  Underhood ID    Veh Class Air Pollution Score  \
# ...

# %%
 df_18.isnull().any(axis=1).sum()
# Out:
# 2

# %%
d_18_null
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1606    False
# 1607    False
# 1608    False
# 1609    False
# 1610    False
# Length: 1611, dtype: bool

# %%
df_18.shape
# Out:
# (1611, 18)

# %%
df_18.duplicated().sum()
# Out:
# 0

# %%
df_18.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                     float64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert Region              object
# Stnd                     object
# Stnd Description         object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score       int64
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Greenhouse Gas Score      int64
# SmartWay                 object
# Comb CO2                 object
# dtype: object

# %%
df_08.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales Area               object
# Stnd                     object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score      object
# FE Calc Appr             object
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Unadj Cmb MPG           float64
# Greenhouse Gas Score     object
# SmartWay                 object
# dtype: object

# %%
df_08.value_counts()
# Out:
# Model            Displ  Cyl      Trans    Drive  Fuel      Sales Area  Stnd  Underhood ID  Veh Class  Air Pollution Score  FE Calc Appr  City MPG  Hwy MPG  Cmb MPG  Unadj Cmb MPG  Greenhouse Gas Score  SmartWay
# GMC Savana 2500  5.3    (8 cyl)  Auto-L4  2WD    Gasoline  CA          L2    8GMXT05.3384  van        6                    Drv           12        16       14       13.8612        2                     no          2
# GMC Savana 1500  5.3    (8 cyl)  Auto-L4  2WD    Gasoline  FA          B5    8GMXT05.3384  van        6                    Drv           12        16       14       13.8612        2                     no          2
#                                           4WD    Gasoline  FA          B5    8GMXT05.3384  van        6                    Drv           12        16       14       13.8375        2                     no          2
# ...

# %%
df_08['SmartWay'].nunique()
# Out:
# 2

# %%
df_18['SmartWay'].nunique()
# Out:
# 3

# %%
df_08['Sales Area'].nunique()
# Out:
# 3

# %%
df_18['Cert Region'].nunique()
# Out:
# 2

# %%
df_08['Trans'].nunique()
# Out:
# 14

# %%
df_08['Cyl'].nunique()
# Out:
# 8

# %%
df_18['Cyl'].nunique()
# Out:
# 7

# %%
df_08.describe()
# Out:
#              Displ  Unadj Cmb MPG
# count  2404.000000    2205.000000
# mean      3.748918      23.916104
# std       1.335785       6.366170
# min       1.300000      10.018400
# 25%       2.500000      19.113900
# 50%       3.500000      23.921300
# 75%       4.800000      27.869300
# max       8.400000      65.777800

# %%
df_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df_18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
df_08[df_08.Fuel == 'Gasoline']
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df_18[df_18.Fuel == 'Gasoline']
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert Region  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1604  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD  Gasoline          FA
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#            Stnd            Stnd Description  Underhood ID     Veh Class  \
# ...

# %%
df_18[df_18.Fuel == 'Ethanol/Gas'].head()
# Out:
#                       Model  Displ  Cyl       Trans Drive         Fuel  \
# 382        CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD  Ethanol/Gas
# 383        CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD  Ethanol/Gas
# 394  CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD  Ethanol/Gas
# 395  CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD  Ethanol/Gas
# 396  CHEVROLET Silverado 15    4.3  6.0      Auto-6   4WD  Ethanol/Gas
#
#     Cert Region      Stnd           Stnd Description  Underhood ID  Veh Class  \
# 382          CA  L3ULEV70  California LEV-III ULEV70  JGMXV03.6166  large car
# 383          FA     T3B70      Federal Tier 3 Bin 70  JGMXV03.6166  large car
# 394          CA  L3ULEV70  California LEV-III ULEV70  JGMXT04.3187     pickup
# 395          FA     T3B70      Federal Tier 3 Bin 70  JGMXT04.3187     pickup
# 396          CA  L3ULEV70  California LEV-III ULEV70  JGMXT04.3187     pickup
#
# ...

# %%
df_08[df_08.Fuel == 'Ethanol/Gas'].head()
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Sales Area, Stnd, Underhood ID, Veh Class, Air Pollution Score, FE Calc Appr, City MPG, Hwy MPG, Cmb MPG, Unadj Cmb MPG, Greenhouse Gas Score, SmartWay]
# Index: []
